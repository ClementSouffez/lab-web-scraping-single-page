# %%
# 1. import libraries
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
#main > div > span > div > div > div.lister > table > tbody > tr:nth-child(1) > td.titleColumn > a

# %%
#main > div > span > div > div > div.lister > table > tbody > tr:nth-child(2) > td.titleColumn

# %%
#  url of the site
url = "https://www.popvortex.com/music/charts/top-100-songs.php"

# %%
# download html with a get request
response = requests.get(url)
response.status_code # 200 status code means OK!
# Out:
# 200

# %%
# parse html (create the 'soup')
soup = BeautifulSoup(response.content, "html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    iTunes Top 100 Songs Chart 2023
#   </title>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="iTunes top 100 songs chart list. The most popular hit music and trending songs of 2023. Chart of today's current iTunes top 100 songs is updated daily." name="description"/>
#   <meta content="iTunes Top 100 Songs Chart 2023" property="og:title">
#    <meta content="Chart of the top 100 songs on iTunes. Chart list of the top 100 song downloads of 2023 is updated daily." property="og:description">
#     <meta content="article" property="og:type">
#      <meta content="https://www.popvortex.com/images/logo-facebook.png" property="og:image"/>
#      <meta content="PopVortex" property="og:site_name"/>
#      <meta content="https://www.popvortex.com/music/charts/top-100-songs.php" property="og:url"/>
#      <meta content="100000239962942" property="fb:admins"/>
# ...

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
#main > div > span > div > div > div.lister > table > tbody > tr:nth-child(1) > td.titleColumn

# %%
#main > div > span > div > div > div.lister > table > tbody > tr:nth-child(1) > td.titleColumn

# %%
# Selector
soup.select("#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > p")
#main > div > span > div > div > div.lister > table > tbody > tr:nth-child(1) > td.titleColumn > a
# Out:
# [<p class="title-artist"><cite class="title">Anti-Hero</cite><em class="artist">Taylor Swift</em></p>]

# %%
soup.select("p.title-artist") # infos about allthe songs
# Out:
# [<p class="title-artist"><cite class="title">Anti-Hero</cite><em class="artist">Taylor Swift</em></p>,
#  <p class="title-artist"><cite class="title">Unholy</cite><em class="artist">Sam Smith &amp; Kim Petras</em></p>,
#  <p class="title-artist"><cite class="title">Heart Like A Truck</cite><em class="artist">Lainey Wilson</em></p>,
#  <p class="title-artist"><cite class="title">Made You Look</cite><em class="artist">Meghan Trainor</em></p>,
#  <p class="title-artist"><cite class="title">Lift Me Up (From Black Panther: Wakanda Forever - Music From and Inspired By)</cite><em class="artist">Rihanna</em></p>,
#  <p class="title-artist"><cite class="title">Temperature</cite><em class="artist">Sean Paul</em></p>,
#  <p class="title-artist"><cite class="title">Son Of A Sinner</cite><em class="artist">Jelly Roll</em></p>,
#  <p class="title-artist"><cite class="title">Separate Ways (Worlds Apart) [feat. Lzzy Hale]</cite><em class="artist">Daughtry</em></p>,
# ...

# %%
#elements containing music titles
soup.select("p.title-artist p")
# Out:
# []

# %%
soup.select("p.title-artist")[0]
soup.select("p.title-artist")[0].get_text()
# Out:
# 'Anti-HeroTaylor Swift'

# %%
soup.select("p.title-artist")[0].get("title")

# %%
#initialize empty lists
title = []
artist = []

# define the number of iterations of our for loop
# by checking how many elements are in the retrieved result set
# (this is equivalent but more robust than just explicitly defining 250 iterations)
num_iter = len(soup.select("p.title-artist"))

tClist = soup.select("p.title-artist")

for i in range(num_iter):
    title.append(tClist[i].get_text())
    artist.append(tClist[i].get("title"))
  
    
print(artist)
print(title)
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# ...

# %%
# each list becomes a column
music = pd.DataFrame({"title":title,
                       "artist":artist
                      })

# %%
music.head()
# Out:
#                                                title artist
# 0                              Anti-HeroTaylor Swift   None
# 1                       UnholySam Smith & Kim Petras   None
# 2                    Heart Like A TruckLainey Wilson   None
# 3                        Made You LookMeghan Trainor   None
# 4  Lift Me Up (From Black Panther: Wakanda Foreve...   None

# %%
len(music)
# Out:
# 100

# %%
# get all elements of a tag
soup.select("p")
# Out:
# [<p>Chart of <strong>iTunes top 100 songs</strong> downloaded at the Apple iTunes music store today. The iTunes top 100 songs chart list countdown includes the hottest and most popular music hits and singles from all musical genres including today's hot <a href="top-pop-songs.php">pop</a>, <a href="top-rap-songs.php">rap</a>, <a href="top-rock-songs.php">rock</a>, and <a href="top-country-songs.php">country</a> songs.</p>,
#  <p>The chart of the current best selling hot 100 song downloads on iTunes right now is updated daily and is for the top singles in the USA.</p>,
#  <p>The number one song on iTunes right now is <strong><a href="https://music.apple.com/us/album/anti-hero/1650841512?i=1650841515&amp;uo=2&amp;partnerId=11&amp;at=10l4UI" rel="nofollow">Anti-Hero by Taylor Swift</a></strong>.</p>,
#  <p>Chart of the top 100 hot tracks and singles <span>last updated: <time>January, 11 2023</time></span></p>,
# ...

# %%
from time import sleep

# %%
for i in range(5):
    print(i)
    sleep(.5)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
from random import randint

# %%
for i in range(5):
    print(i)
    wait_time = randint(1,4000)
    print("I will sleep for " + str(wait_time/1000) + " seconds.")
    sleep(wait_time/1000)
# Out:
# 0
# I will sleep for 3.246 seconds.
# 1
# I will sleep for 1.963 seconds.
# 2
# I will sleep for 0.762 seconds.
# 3
# I will sleep for 3.27 seconds.
# 4
# I will sleep for 1.679 seconds.

# %%
iterations = range(1, 610, 50)
[i for i in iterations]
# Out:
# [1, 51, 101, 151, 201, 251, 301, 351, 401, 451, 501, 551, 601]

# %%
iterations = range(1, 200, 50)
[i for i in iterations]
# Out:
# [1, 51, 101, 151]
